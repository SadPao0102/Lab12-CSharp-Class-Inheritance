// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Using a references to a base class

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex13
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```cs
// DerivedClass DC = new DerivedClass();
// System.Console.WriteLine($"DC.Field1 = {DC.Field1}");
//
// BaseClass BC = (BaseClass)DC;
// System.Console.WriteLine($"BC.Field1 = {BC.Field1}");
//
// class BaseClass
// {
//     public string Field1 = "Field1 of BaseClass";
// }
// class DerivedClass:BaseClass
// {
//     new public string Field1 = "Field1 of DerivedClass";
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex13
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex13
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// การซ่อนตัวแปร: ตัวแปร Field1 ใน DerivedClass ซ่อนตัวแปร Field1 ของ BaseClass ทำให้เรียก DC.Field1 ได้ค่าจาก DerivedClass
//
// การแปลงประเภท: เมื่อแปลง DC เป็น BaseClass การเรียก BC.Field1 จะได้ค่าจาก BaseClass แทน
//
// ผลลัพธ์:
//
// DC.Field1 แสดง "Field1 of DerivedClass"
//
// BC.Field1 แสดง "Field1 of BaseClass"
